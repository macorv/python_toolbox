# %% [markdown]
# **Seccion Politica**
#
# `https://buscar.lanacion.com.ar/politica/c-Pol%C3%ADtica/date-20180101,20180829/page-2`
#
# **Seccion Economia**
#
# `https://buscar.lanacion.com.ar/economia/c-Econom%C3%ADa/date-20180101,20180829/page-2`
#
# **Seccion Turimos**
# `https://buscar.lanacion.com.ar/turismo/c-Turismo/page-2/date-20180101,20180829/page-2`
#
# Arbol de la pagina para buscar los links:
#
# `<div id="contenedor">
#     <div class="subContenedor floatFix">
#         <div class="centroBuscador">
#             <ul class="acumuladosBuscador">
#                 <li class="floatFix notas">
#                     <span class="tituloNota">
#                         <h2>
#                             <a href=""</a>
# `

# %%
# Importamos las librerias necesarias para construir el scrapper
import requests #Para bajar el HTML
import bs4 # Para parsear el HTML
import time # Para grabar fecha
import datetime # Para grabar fecha y hora
import os # Para crear carpeta

from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

# Configuraciones Requests
session = requests.Session()
retry = Retry(connect=3, backoff_factor=0.5)
adapter = HTTPAdapter(max_retries=retry)
session.mount('http://', adapter)
session.mount('https://', adapter)

# %%
# Parametros configurables 
# Guardo en un archivo de texto, para tener registro de las ejecuciones 
carpetaBase = '/Users/martin/Documents/GitHub/toolbox_python/scraper-log/'

# Armo el nombre del archivo en base a la fecha en que se corre. Es el log del archivo
fileNameBase = 'Ejecucion_'

# URL de busqueda 
urlBase = 'https://buscar.lanacion.com.ar/'

# Opciones de busqueda para la nacion 
urlOpciones = ["turismo/c-Turismo"]
#urlOpciones = [ "politica/c-Pol%C3%ADtica", "economia/c-Econom%C3%ADa" , "turismo/c-Turismo"]

# Opciones de busqueda para las fechas (este parametro puede ser automatizado)
urlFecha = ['date-20180101,20180829','date-20170601,20171231','date-20170101,20170531','date-20160601,20161231', 'date-20160101,20160531','date-20150601,20151231', 'date-20150101,20150531','date-20140601,20141231', 'date-20140101,20140531','date-20130601,20131231', 'date-20130101,20130531','date-20120601,20121231', 'date-20120101,20120531','date-20110601,20111231', 'date-20110101,20110531','date-20100601,20101231', 'date-20100101,20100531']

# Opciones de pagina (este parametro puede ser automatizado)
urlPaginas = 401

# Visual para saber que empieza
print("Empieza")

# Obtengo la fecha 
ts = time.time()

# Armo la fecha 
fileNameDate = datetime.datetime.fromtimestamp(ts).strftime('%Y-%m-%d_%H-%M-%S')

# Armo el nombre 
fileName = carpetaBase + fileNameBase + fileNameDate + '.txt'
print("Nombre del archivo:", fileName)

# Declaro la variable para manejar el archivo 
file = open(fileName,'w+')

# Mensaje para saber que se esta haciendo 
print("Vamos a ver noticias de: " + urlBase )
file.write("Vamos a ver noticias de: " + urlBase + '\n\n' )

# Defino funcion para que me saque los videos de las notas
# Hay que mejorarlo!!!
def not_video(tag):
    return not tag.div

# Ahora la idea es recorrer cada categoria que esta en el parametro de urlOpciones 
# Dentro de cada parametro, vamos a traer los links de cada pagina
# Y de cada URL sacamos el texto, solo nos interesa la nota

for seccion in urlOpciones:
    seccionSplit = seccion.split('/')[0]
    pathCarpeta = './articulos/'+seccionSplit
    '''Creamos la carpeta donde se van a guardar los articulos'''
    os.makedirs(pathCarpeta, exist_ok = True)
    print("Para la seccion: " + seccionSplit)
    file.write("Para la seccion: " + seccionSplit + '\n' )
    '''Ahora tengo que recorrer cada pagina '''
    for fecha in urlFecha:
        for pagina in range(1,urlPaginas,5):
            print("Tengo en pagina: ", pagina)
            '''Armo la URL de donde voy a traer las noticias'''
            urlParaRevisar = urlBase + seccion + '/' + fecha + '/page-' + str(pagina)
            print("La url es: " + urlParaRevisar)
            file.write("\t La url es: " + urlParaRevisar + '\n' )
            '''Requests sobre la pagina'''
            lnPagBuscador = session.get(urlParaRevisar)
            try:
                lnPagBuscador.raise_for_status()
            except Exception as exc:
                print('Hubo un problema: %s' %exc)
                file.write("\t\t Error en este link" + '\n')
            '''Me aseguro que el encoding sea el correcto, tiene que estar en Español'''
            lnPagBuscador.encoding = 'utf-8'
            '''Empiezo a parsear con BeautifulSoup el archivo HTML'''
            lnSoup = bs4.BeautifulSoup(lnPagBuscador.text, 'html.parser')
            '''Busco la parte del HTML donde se encuentran los links a las notas. Se guarda en una lista'''
            elems = lnSoup.select('span > h2 > a')
            '''Me quedo unicamente con los links a las notas'''
            for k,i in enumerate(elems):
                '''Empiezo a recorrer la lista de URLs para bajarme el texto'''
                urlParaBajar = elems[k].get('href')
                print('Bajando HTML de: ' + urlParaBajar)
                file.write("\t\t" + 'Bajando HTML de: ' + urlParaBajar  + '\n' )
                nombreArticulo = urlParaBajar.split('/')[3]
                articulos = open(pathCarpeta + '/' + nombreArticulo + '.txt', 'w+')
                lnArticulo = requests.get(urlParaBajar)
                try:
                    lnArticulo.raise_for_status()
                except Exception as exc:
                    print('Hubo un problema: %s' %exc)
                    file.write("\t\t Error en este link" + '\n')
                '''Empiezo a bajar cada HTML'''
                lnArticulo.encoding = 'utf-8'
                notaSoup = bs4.BeautifulSoup(lnArticulo.text, 'html.parser')
                textoNota = notaSoup.select('section[id="cuerpo"] > p')
                for texto in textoNota:
                    if not_video(texto) == True:
                        ext = texto.get_text(' ',strip=True)
                        print('Guardando texto en archivo...')
                        file.write('Guardando texto en archivo...')
                        articulos.write(ext + '\n')
                        print('Listo')
                        file.write('Listo')
                    else:
                        continue
                articulos.close()


print("Termino")
file.close()

# AGREGAR MULTITHREADING
# Out:
# Empieza
# Nombre del archivo: /Users/martin/Documents/GitHub/toolbox_python/scraper-log/Ejecucion_2018-09-04_23-28-23.txt
# Vamos a ver noticias de: https://buscar.lanacion.com.ar/
# Para la seccion: turismo
# Tengo en pagina:  1
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-1
# Bajando HTML de: http://www.lanacion.com.ar/2163140-menos-compras-mas-aventuras-gastronomia-turismo-astronomico
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2163141-otra-cara-del-turismo-aventura-temores-de-una-madre-ante-el-abismo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2165498-travel-sale-2018-que-tener-cuenta-obtener
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2165118-tres-altos-senderos-puna
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2165116-noche-suspenso-enigmatica-hosteria-sudafricana
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2160943-valeria-mazza-me-han-malcriado-mucho
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2165117-garantia-sol-estos-cinco-lugares-casi-nunca
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2146241-recalculando-destinos-el-turismo-siente-los-efectos-de-la-devaluacion
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2160939-un-amanecer-en-namibia-arena-360-en-el-desierto-mas-antiguo-del-mundo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2139756-nuevos-rumbos-para-el-turismo-de-lujo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Tengo en pagina:  6
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-6
# Bajando HTML de: http://www.lanacion.com.ar/2123063-laura-azcurra-estuve-varada-tres-dias-en-hong-kong
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2131270-un-riesgoso-bautismo-de-buceo-en-honduras
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2113336-magui-bravi-trabaje-como-azafata-de-cabotaje
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2129766-la-antartida-cada-vez-mas-turistica
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2109162-yibuti-el-pais-africano-que-segun-lonely-planet-todos-deberiamos-visitar-este-ano
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2135894-8-restaurantes-en-mendoza-que-vale-la-pena-conocer
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2139759-un-ferrocarril-legendario-en-el-corazon-de-rusia
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2119383-cinco-hits-imperdibles-en-napoles-y-alrededores
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2158744-como-viajar-todo-un-ano-canjeando-millas
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2158746-en-nueva-zelanda-un-parque-para-caminar-durante-dias
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Tengo en pagina:  11
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-11
# Bajando HTML de: http://www.lanacion.com.ar/2156237-las-10-etapas-que-superamos-para-decidir-dejar-la-ciudad-y-vivir-en-el-agua
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2135896-mundial-rusia-2018-la-guia-basica-de-moscu-que-necesitas-antes-de-viajar
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2099809-un-dia-tipico-en-laos-del-picadito-en-la-vereda-al-bano-de-elefantes
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2109480-verano-en-las-sierras-merlo-en-plan-familiar
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2144038-en-dos-ruedas-a-un-volcan-que-pocos-conocen
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2124993-dormir-entre-vinedos-las-mejores-bodegas-para-alojarse-de-mendoza-a-salta
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2097843-dioses-demonios-y-misterio-en-los-templos-de-angkor-wat-de-camboya
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2119385-coney-island-astoria-y-belmont-barrios-de-nueva-york-para-descubrir
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2154659-la-magica-montana-de-saint-michel
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2105806-natalia-lafourcade-mi-dia-de-vacaciones-perfecto-seria-en-casa
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Tengo en pagina:  16
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-16
# Bajando HTML de: http://www.lanacion.com.ar/2144035-esqui-2018-precios-y-novedades-centro-por-centro
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2129763-kate-la-robot-que-te-ayuda-a-hacer-el-check-in
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2129762-cinco-grandes-shows-ecuestres-para-galopar-desde-peru-hasta-islandia
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2113332-salzburgo-me-devuelve-la-sonrisa
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2113331-la-moda-de-las-estaciones-de-servicio-recicladas-como-restaurantes
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2128297-un-chico-de-12-anos-les-robo-la-tarjeta-de-credito-a-sus-padres-y-viajo-solo-a-bali
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2127127-escritores-argentinos-como-en-su-casa
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2127185-el-arte-de-sumar-millas-trucos-para-viajeros-no-tan-frecuentes
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2127122-carolina-peleritti-viajar-es-como-despertar
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2125018-geiseres-la-excursion-mas-hot
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Tengo en pagina:  21
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-21
# Bajando HTML de: http://www.lanacion.com.ar/2112357-este-castillo-frances-inspiro-a-los-creadores-de-la-bella-y-la-bestia-y-se-nota
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2103103-el-outlet-premium-a-40-minutos-de-barcelona-que-todos-deberian-conocer
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2133684-hot-sale-2018-10-consejos-para-conseguir-pasajes-de-avion-baratos
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2101872-praga-huellas-del-pasado-por-las-calles-del-barrio-judio
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2101869-de-orlando-a-londres-cinco-parques-tematicos-de-pelicula
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2133370-mundial-rusia-2018-como-dominar-el-transporte-publico-de-moscu
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2099915-top-five-para-melomanos-calles-que-inspiraron-canciones-y-discos
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2131640-londres-desde-una-perspectiva-mas-real
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2097845-cinco-sitios-argentinos-para-seguir-huellas-afro
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/2105633-el-museo-de-bonsais-con-3000-arboles-miniatura-de-70-especies-diferentes
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Tengo en pagina:  26
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-26
# Tengo en pagina:  31
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-31
# Tengo en pagina:  36
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-36
# Tengo en pagina:  41
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-41
# Tengo en pagina:  46
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-46
# Tengo en pagina:  51
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-51
# Tengo en pagina:  56
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-56
# Tengo en pagina:  61
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-61
# Tengo en pagina:  66
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-66
# Tengo en pagina:  71
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-71
# Tengo en pagina:  76
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-76
# Tengo en pagina:  81
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-81
# Tengo en pagina:  86
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-86
# Tengo en pagina:  91
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-91
# Tengo en pagina:  96
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-96
# Tengo en pagina:  101
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-101
# Tengo en pagina:  106
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-106
# Tengo en pagina:  111
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-111
# Tengo en pagina:  116
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-116
# Tengo en pagina:  121
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-121
# Tengo en pagina:  126
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-126
# Tengo en pagina:  131
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-131
# Tengo en pagina:  136
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-136
# Tengo en pagina:  141
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-141
# Tengo en pagina:  146
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-146
# Tengo en pagina:  151
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-151
# Tengo en pagina:  156
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-156
# Tengo en pagina:  161
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-161
# Tengo en pagina:  166
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-166
# Tengo en pagina:  171
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-171
# Tengo en pagina:  176
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-176
# Tengo en pagina:  181
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-181
# Tengo en pagina:  186
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-186
# Tengo en pagina:  191
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-191
# Tengo en pagina:  196
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-196
# Tengo en pagina:  201
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-201
# Tengo en pagina:  206
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-206
# Tengo en pagina:  211
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-211
# Tengo en pagina:  216
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-216
# Tengo en pagina:  221
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-221
# Tengo en pagina:  226
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-226
# Tengo en pagina:  231
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-231
# Tengo en pagina:  236
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-236
# Tengo en pagina:  241
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-241
# Tengo en pagina:  246
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-246
# Tengo en pagina:  251
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-251
# Tengo en pagina:  256
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-256
# Tengo en pagina:  261
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-261
# Tengo en pagina:  266
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-266
# Tengo en pagina:  271
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-271
# Tengo en pagina:  276
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-276
# Tengo en pagina:  281
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-281
# Tengo en pagina:  286
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-286
# Tengo en pagina:  291
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-291
# Tengo en pagina:  296
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-296
# Tengo en pagina:  301
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-301
# Tengo en pagina:  306
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-306
# Tengo en pagina:  311
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-311
# Tengo en pagina:  316
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-316
# Tengo en pagina:  321
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-321
# Tengo en pagina:  326
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-326
# Tengo en pagina:  331
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-331
# Tengo en pagina:  336
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-336
# Tengo en pagina:  341
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-341
# Tengo en pagina:  346
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-346
# Tengo en pagina:  351
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-351
# Tengo en pagina:  356
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-356
# Tengo en pagina:  361
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-361
# Tengo en pagina:  366
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-366
# Tengo en pagina:  371
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-371
# Tengo en pagina:  376
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-376
# Tengo en pagina:  381
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-381
# Tengo en pagina:  386
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-386
# Tengo en pagina:  391
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-391
# Tengo en pagina:  396
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20180101,20180829/page-396
# Tengo en pagina:  1
# ...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/1232581-la-chaya-amor-de-leyenda
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/1232570-lanacioncom
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/1232576-de-rio-a-ushuaia-en-un-omnibus-dificil-de-ignorar
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Tengo en pagina:  26
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-26
# Bajando HTML de: http://www.lanacion.com.ar/1240613-las-mil-caras-de-toronto
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/1269921-la-mejor-parrilla-de-ruta-en-el-mundo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/1269132-apasionados-por-el-chocolate
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/1267777-con-la-mente-en-blanco
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/1267449-de-casa-al-trabajo-en-lancha
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/1264813-cartelera-cultural
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/1262362-el-glamour-de-niza-en-clase-turista
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/1262357-bird-watching-a-vista-de-pajaro
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/1261803-feria-de-mataderos-un-mercado-a-cielo-abierto
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Bajando HTML de: http://www.lanacion.com.ar/1260149-un-argentino-en-moto-por-la-ruta-de-la-seda
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Guardando texto en archivo...
# Listo
# Tengo en pagina:  31
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-31
# Tengo en pagina:  36
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-36
# Tengo en pagina:  41
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-41
# Tengo en pagina:  46
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-46
# Tengo en pagina:  51
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-51
# Tengo en pagina:  56
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-56
# Tengo en pagina:  61
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-61
# Tengo en pagina:  66
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-66
# Tengo en pagina:  71
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-71
# Tengo en pagina:  76
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-76
# Tengo en pagina:  81
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-81
# Tengo en pagina:  86
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-86
# Tengo en pagina:  91
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-91
# Tengo en pagina:  96
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-96
# Tengo en pagina:  101
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-101
# Tengo en pagina:  106
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-106
# Tengo en pagina:  111
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-111
# Tengo en pagina:  116
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-116
# Tengo en pagina:  121
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-121
# Tengo en pagina:  126
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-126
# Tengo en pagina:  131
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-131
# Tengo en pagina:  136
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-136
# Tengo en pagina:  141
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-141
# Tengo en pagina:  146
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-146
# Tengo en pagina:  151
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-151
# Tengo en pagina:  156
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-156
# Tengo en pagina:  161
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-161
# Tengo en pagina:  166
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-166
# Tengo en pagina:  171
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-171
# Tengo en pagina:  176
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-176
# Tengo en pagina:  181
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-181
# Tengo en pagina:  186
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-186
# Tengo en pagina:  191
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-191
# Tengo en pagina:  196
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-196
# Tengo en pagina:  201
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-201
# Tengo en pagina:  206
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-206
# Tengo en pagina:  211
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-211
# Tengo en pagina:  216
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-216
# Tengo en pagina:  221
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-221
# Tengo en pagina:  226
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-226
# Tengo en pagina:  231
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-231
# Tengo en pagina:  236
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-236
# Tengo en pagina:  241
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-241
# Tengo en pagina:  246
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-246
# Tengo en pagina:  251
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-251
# Tengo en pagina:  256
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-256
# Tengo en pagina:  261
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-261
# Tengo en pagina:  266
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-266
# Tengo en pagina:  271
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-271
# Tengo en pagina:  276
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-276
# Tengo en pagina:  281
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-281
# Tengo en pagina:  286
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-286
# Tengo en pagina:  291
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-291
# Tengo en pagina:  296
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-296
# Tengo en pagina:  301
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-301
# Tengo en pagina:  306
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-306
# Tengo en pagina:  311
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-311
# Tengo en pagina:  316
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-316
# Tengo en pagina:  321
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-321
# Tengo en pagina:  326
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-326
# Tengo en pagina:  331
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-331
# Tengo en pagina:  336
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-336
# Tengo en pagina:  341
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-341
# Tengo en pagina:  346
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-346
# Tengo en pagina:  351
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-351
# Tengo en pagina:  356
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-356
# Tengo en pagina:  361
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-361
# Tengo en pagina:  366
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-366
# Tengo en pagina:  371
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-371
# Tengo en pagina:  376
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-376
# Tengo en pagina:  381
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-381
# Tengo en pagina:  386
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-386
# Tengo en pagina:  391
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-391
# Tengo en pagina:  396
# La url es: https://buscar.lanacion.com.ar/turismo/c-Turismo/date-20100101,20100531/page-396
# Termino
